# %% [markdown]
# # Objective for Part 3
#
# As a recap, previously in Part 1 we cleaned our data to remove missing values, convert into lower cases and remove punctuations. For Part 2, we perform analyis using WordCloud to visualize what are the keywords in classifying the Urban Dictionary definitions as misogynistic or non-misogynistic.
#
# In Part 3, we will
# - Perform another round of data cleaning: remove stopwords. This is essential for the next step.
# - Perform Tfidf Vectorization on data without stopwords.
# - Split data into training and test set.
# - Train 4 classification models using the training set: DummyClassifier, LogisticRegression, DecisionTreeClassifier, RandomForestClassifier.
# - For each model, calculate the F1 scores and confusion matrix using the predictions and actual target data from test set.
# - From the best model, extract the feature importance attribute to see which features contribute heavily in the classifications.
# - Based on the number of important features, adjust the number of features used in the best model's training to obtain a more efficient model.
# - Test model with unseen data to see if the predictions are accurate by creating some strings with misogynistic and non-misogynistic words.

# %%
# Step 1: Import your libraries 
import pandas as pd
from wordcloud import STOPWORDS

print(STOPWORDS)
# Out:
# {'further', 'i', "isn't", "you're", 'at', 'theirs', 'again', "how's", 'nor', 'most', 'why', 'for', 'few', 'had', 'otherwise', 'their', "they're", 'through', 'while', 'does', 'which', 'because', "who's", "we've", "shan't", 'been', 'between', 'myself', "they'll", "where's", "i'd", 'she', 'its', 'however', 'down', "what's", "when's", 'you', 'be', "doesn't", "here's", "he'll", 'did', 'of', 'it', "wasn't", 'else', 'yourselves', 'is', "haven't", 'do', 'out', "they've", 'like', 'who', 'there', "aren't", 'these', 'your', "won't", 'how', "shouldn't", 'more', 'my', 'also', 'yourself', "couldn't", 'her', 'me', "didn't", 'they', 'only', 'k', 'therefore', 'after', "let's", 'same', 'themselves', 'here', 'get', 'during', "he'd", 'yours', "we'll", "hadn't", 'ourselves', 'having', 'him', 'himself', 'itself', 'or', "don't", 'own', 'if', 'but', "it's", "hasn't", 'too', 'with', 'our', "she'd", 'so', 'up', 'was', 'the', 'above', 'both', 'into', 'shall', "i'll", "can't", 'over', 'herself', 'ought', 'cannot', 'then', 'are', 'would', 'whom', 'in', 'such', 'hers', "we'd", 'as', "you'd", 'could', 'on', "i'm", 'doing', 'and', 'before', 'under', "she'll", 'should', 'once', 'where', 'below', 'his', 'some', 'r', "you've", 'this', 'ever', 'hence', 'that', 'we', 'were', 'those', 'have', 'against', "we're", 'than', "i've", 'what', 'from', 'each', 'http', "that's", "they'd", 'com', 'other', 'not', "wouldn't", "she's", 'any', 'no', "there's", 'all', 'very', 'he', 'a', 'since', "he's", 'am', 'www', 'being', "mustn't", 'off', 'to', 'about', 'can', 'just', 'when', 'an', "why's", "weren't", 'ours', 'has', 'by', 'until', 'them', "you'll"}

# %%
# Step 2: Read your CSV
df = pd.read_csv("ManualTag_Misogyny_Clean.csv", index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2286 entries, Ur gonna die... queer to That hoe out there!!!
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   is_misogyny         2286 non-null   float64
#  1   cleaned_definition  2286 non-null   object
# dtypes: float64(1), object(1)
# memory usage: 53.6+ KB

# %%
# Step 3: Remove stopwords from the text in 'cleaned_definition'
stop = list(STOPWORDS)

#for every word in s, check and add to list if it's not stop word
#returns a string of no stopwords
def remove_stopwords(s):
    list_nostop = [item for item in s.split() if item not in stop]
    return " ".join(list_nostop)

df['cleaned_definition_nostop'] = df['cleaned_definition'].map(remove_stopwords)

# %%
# Step 4: Import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
print(df['cleaned_definition_nostop'].tolist())
# Out:
# ['ur gonna die queer', 'valuptuous man boobs', 'variation brother', 'impressive penis', 'call penis', 'real man eats', 'every man fears', 'named dick', 'gay guy farts', 'man ejaculates', 'man jacks', 'man gets boner', 'two bros frolic', 'gay ugly', 'whip penis', 'fuck', 'ate pies', 'cares fake', 'young bisexual male', 'buttsex rearranged', 'slang lesbian', 'cum bubble thera', 'penis butt', 'short dick syndrome', 'vampire brothel', 'babys vaginal lips', 'batty riders penis', 'beaner fob', 'big jewish softcock', 'black persons cock', 'bonham w 2 cock', 'bro taking shower', 'bro retarded', 'broke mans cadillac', 'broken glass bottle', 'brown girls bosom', 'brown skined person', 'burnt severed penis', 'chineese black man', 'codename penis', 'complete cock block', 'complete homosexual', 'complex sexual move', 'damn sexy beast etc', 'dirty niggers cock', 'drizzle gizcum', 'extremely gay thing', 'fag homosexual', 'fart penis', 'flamboyant gay male', 'flaming homosexual', 'friend cheap', 'fucking gay bastard', 'gang gay niggas', 'gay ass cook sucker', 'gay fag sesion', 'gay lingo liar', 'gay monkey creature', 'guy cant spell', 'guy likes cake', 'guy masterbates', 'heterosexual person', 'hoe prostitute', 'homo likes cock', 'homosexual japanese', 'homosexual werewolf', 'large big penis', 'large penis doom', 'long stretchy penis', 'long word penis', 'long skinny penis', 'male cats genitalia', 'man dressed drag', 'man airforce', 'man asian origin', 'man rapes cats', 'man sells weed', 'man big cock', 'man mandingo', 'man long hair', 'mans flaccid penis', 'meister cunts', 'mexican emo', 'midget black', 'mohawk cock', 'narcoleptic lesbian', 'new way say porn', 'nice loving brother', 'overly large penis', 'penis slammed', 'penis enlarger pill', 'penis short fat', 'penis bumpy', 'penis foreskin', 'person cheap', 'person cheap', 'person taxed', 'person twitters', 'phone sex solicitor', 'pit stop sex', 'place store porn', 'player ia ra3', 'rapeist gay', 'rather large penis', 'really gay hair cut', 'regular sized penis', 'request gay sex', 'retarded homosexual', 'sexual looking duck', 'sexy hot person', 'sexy ass pig fucker', 'sharp flat penis', 'short stubby penis', 'shy queer young boy', 'sissy gay dude', 'slang dickwad', 'small penis bud', 'smelly fucking cunt', 'squidward nosed gay', 'stray eyebrow hair', 'suppressed lesbian', 'term sex', 'term sex', 'transexual grandma', 'transvestite hooker', 'type brown hair', 'uncircumsized penis', 'verry sexsay person', 'hairy dickhead', 'homosexual man', 'sexy man', 'big penis', 'virus penis', 'wanker swaggers', 'way saying pussy', 'white boy raps', 'white boy raps', 'white boy raps', 'white boy raps', 'white boy raps', 'wierd looking penis', 'word homosexual', 'abreviation penis', 'adj gay n gay', 'aka vaginal discharge', 'bros everywhere', 'mighty translator', 'allen rogerss penis', 'amazingly sexy person', 'male threesome', 'extremely sexy man', 'inside penis', 'old school brothel', 'old wrinkley penis', 'uncircumcised male', 'uncircumcised man', 'unforgetable penis', 'angry lesbians united', 'anime gay people', 'another term gays', 'another term sex', 'another term sex', 'another word cock', 'another word cock', 'another word cock', 'another word cum', 'another word cum', 'another word cum', 'another word cum', 'another word cunt', 'another word porn', 'another word sex', 'another word sex', 'form penis hug', 'anything penis', 'hot ones penis', 'ask someone cares', 'basically penis', 'basically penis', 'batty bwoy gay man', 'beautiful nice sexy', 'queer fag', 'bent crooked penis', 'big gay hunk meat', 'bit gayish nerd term', 'bring cunts', 'broads born japan', 'broke wit boo', 'broken hearted homie', 'bros roller blading', 'brown teeth tits', 'browsing internet', 'brunch 2 bros', 'cajun french cock', 'chav word brother', 'cheque cockney slang', 'cock loveing mexicans', 'cockney fight', 'cocksucker max', 'comfy scum', 'commerciel sex worker', 'crazy german buttsex', 'creamy vaginal fluids', 'cumming  ...

# %%
corpus = df['cleaned_definition_nostop'].tolist()

# Step 5a: Declare your TfidVectorizer object
vectorizer = TfidfVectorizer()

# Step 5b: Perform a fit_transform method with the 'cleaned_definition_nostop' column values
X = vectorizer.fit_transform(corpus)

# %%
print(vectorizer.get_feature_names())
# Out:
# ['010', '02', '034', '04', '0702pm', '0708pm', '07rnrntheir', '095lbsrnbirthday', '0chan', '10', '100', '1000', '100000', '1000s', '100m', '100s', '101', '103', '10cup', '10th', '11', '110', '1100', '1120am', '1129am', '1134am', '1136am', '117', '12', '12rnthe', '12th', '13', '1337', '1338', '135', '1350', '137rnrnborn', '13th', '14', '15', '15000', '1500s', '151', '1516', '1530s', '155chinknn2', '1583', '1590nnmany', '16', '160', '168', '17', '1750', '179', '1790s', '18', '180', '1823', '18481933', '18nnin', '19', '1920s', '1934', '1939', '1940', '1940and', '1941', '1941spring', '1942', '1942winter', '1943', '1944', '1948', '1950s', '19582009', '1960', '1960s', '1961', '1964', '1968', '1970', '1970s', '1970srn5', '1971', '1971nnii', '1972', '1973', '1979', '1979rnrnafter', '1980s', '1982', '1983', '1984', '1985', '1987', '1988', '1988rnrntransitive', '1989', '1990s', '1991', '1992', '1993', '1995', '1996', '1997', '19992009', '1a', '1california', '1generally', '1goths', '1nna', '1rnaddress', '1st', '1the', '1ton', '1v', '1when', '1wood', '20', '200', '2000', '2001', '2002', '2003', '2004', '2005', '2005rnrnhe', '2005rnrnkanye', '2005rnrnsome', '2006', '2006rnkaiuwe', '2007', '2007rnau', '2007rneu', '2008', '2008rnrn4', '2009', '2009rnhttpwwwtimesonlinecouktolcommentcolumnistsben_macintyrearticle5663234ece', '2010', '2010nn', '2012', '2014', '2030', '2050', '20s', '20something', '20th', '21', '210', '21200', '21st', '22', '23', '24', '242', '247', '247rnif', '24ft', '25', '25000', '258', '25th', '26', '27gook', '28', '28th', '29', '298', '2nd', '2nna', '2on2', '2rnaddress', '2the', '30', '300', '305', '305area', '30s', '33mm', '34', '34567898', '35', '360', '3601', '38', '39', '395', '3cm', '3day', '3nigger5kike', '3on3', '3rd', '40', '400', '403', '40degrees', '40s', '41', '411', '44', '45', '46', '4chan', '4on4rnrn2', '4pm', '4wd', '4x4', '50', '500', '50000', '500000', '50100', '52', '520', '55', '55hp', '57mmrnrnthe', '59', '5th', '60', '600', '60000', '60s', '62', '64rnû147', '65', '65782', '68', '69', '69ingrnrnoral', '6th', '70', '70000nnand', '700mg', '7085', '70s', '70srnsome', '70yearold', '741', '75', '77', '792', '792mm', '7am', '7eleven', '7pm', '7sophomore', '7th', '7thrnbloodtype', '800', '800mm', '80s', '80srnrnall', '83', '85', '860000', '8795', '8th', '90', '90s', '911', '917', '92', '92400nnû488', '95', '9521056', '99', '999', '99999', '9pm', '9th', 'a2m', 'a_òü', 'aarc', 'aaron', 'ab5csya', 'abandon', 'abandoned', 'abandoning', 'abandons', 'abberiviation', 'abbey', 'abbeys', 'abbotabad', 'abbr', 'abbrasive', 'abbreviated', 'abbreviation', 'abby', 'abc', 'abducts', 'abe', 'abel', 'abercrombie', 'abide', 'abigail', 'abilities', 'ability', 'abk', 'able', 'ablicious', 'abnormal', 'abnormally', 'abode', 'abomb', 'abominable', 'abomonation', 'aboriginal', 'abort', 'abortion', 'abortions', 'aboutclothes', 'abraham', 'abreviation', 'abroad', 'absolute', 'absolutely', 'absolutley', 'absolutly', 'absorb', 'absorbed', 'absorped', 'absrnthese', 'abstinence', 'abstinenceonly', 'abstract', 'absurdity', 'absurdly', 'abu', 'aburame', 'abuse', 'abused', 'abusers', 'abuses', 'abusing', 'abusive', 'ac', 'academic', 'accelerates', 'accent', 'accentnnsocial', 'accents', 'accept', 'acceptable', 'acceptablernrn4', 'acceptance', 'accepted', 'accesories', 'access', 'accessories', 'accessoriesrn', 'accessoryrnrni', 'accident', 'accidental', 'accidentally', 'accidentaly', 'acclaim', 'accommodate', 'accomodation', 'accompanied', 'accompany', 'accomplish', 'accomplished', 'accomplishment', 'accomplishments', 'accordin', 'according', 'accordinglyexemplified', 'accosted', 'account', 'accountable', 'accounts', 'accoutrements', 'accumulation', 'accuracy', 'accurate', 'accurately', 'accusations', 'accused', 'accustomed', 'accutely', 'acehigh', 'acehrnrnpointed', 'achaeologic', 'ache', 'achieve', 'achieved', 'achieving', 'achilles', 'acid', 'acidic', 'ackles', 'acknowledge', 'acknowledgement', 'acknowledgements', 'acknowledges', 'aclaimed',  ...

# %%
print(X.shape)
# Out:
# (2286, 16289)

# %%
# Step 6: Convert the sparse matrix into a DataFrame
df_X = pd.DataFrame.sparse.from_spmatrix(X, columns=vectorizer.get_feature_names())

# %%
# Step 7: Import your ML libraries
from  sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, confusion_matrix

# %%
# Step 8: Prepare your independent variables
y = df['is_misogyny']

# %%
# Step 9: Split your data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df_X, y, test_size=0.2, stratify=y)

# %%
# Step 10a: Declare a variable to store the DummyClassifier model
dummy_clf = DummyClassifier()

# Step 10b: Fit your train dataset
dummy_clf.fit(X_train, y_train)

# Step 10c: Declare a variable and store your predictions that you make with your model using X test data
prediction = dummy_clf.predict(X_test)

# Step 10d: Print the f1_score between the y test and prediction
print(f1_score(y_test, prediction))

# Step 10e: Print the confusion matrix using the y test and prediction
print(confusion_matrix(y_test, prediction))
# Out:
# 0.42685851318944845
# [[130 121]
#  [118  89]]
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/dummy.py:131: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   warnings.warn("The default value of strategy will change from "

# %%
# Step 11a: Declare a variable to store the LogisticRegression model
lr = LogisticRegression()

# Step 11b: Fit your train dataset
lr.fit(X_train, y_train)

# Step 11c: Declare a variable and store your predictions that you make with your model using X test data
pred_lr = lr.predict(X_test)

# Step 11d: Print the f1_score between the y test and prediction
print(f1_score(y_test, pred_lr))

# Step 11e: Print the confusion matrix using the y test and prediction
print(confusion_matrix(y_test, pred_lr))
# Out:
# 0.8133704735376045
# [[245   6]
#  [ 61 146]]

# %%
# Step 12: Train a DecisionTreeClassifer model
# Step 12a: Declare a variable to store the DecisionTreeClassifer model
tree = DecisionTreeClassifier()

# Step 12b: Fit your train dataset
tree.fit(X_train, y_train)

# Step 12c: Declare a variable and store your predictions that you make with your model using X test data
pred_tree = tree.predict(X_test)

# Step 12d: Print the f1_score between the y test and prediction
print(f1_score(y_test, pred_tree))

# Step 12e: Print the confusion matrix using the y test and prediction
print(confusion_matrix(y_test, pred_tree))
# Out:
# 0.8640776699029126
# [[224  27]
#  [ 29 178]]

# %%
# Step 13: Train a RandomForestClassifier model
# Step 13a: Declare a variable to store the RandomForestClassifier model
rf = RandomForestClassifier()

# Step 13b: Fit your train dataset
rf.fit(X_train, y_train)

# Step 13c: Declare a variable and store your predictions that you make with your model using X test data
pred_rf = rf.predict(X_test)

# Step 13d: Print the f1_score between the y test and prediction
print(f1_score(y_test, pred_rf))

# Step 13e: Print the confusion matrix using the y test and prediction
print(confusion_matrix(y_test, pred_rf))
# Out:
# 0.8984771573604061
# [[241  10]
#  [ 30 177]]

# %%
# Step 14: Create a DataFrame containing the feature importances of your model and sort! 
df_rf = pd.DataFrame(rf.feature_importances_, index=df_X.columns, columns=['feature importance'])

# %%
df_rf[df_rf['feature importance'] > 0].sort_values(by='feature importance',ascending=False)
# Out:
#               feature importance
# vagina              6.695843e-02
# female              5.572821e-02
# pussy               3.473789e-02
# woman               2.875108e-02
# penis               1.479593e-02
# ...                          ...
# hernnnote           5.151689e-09
# philadelphia        4.619423e-09
# techno              4.582008e-09
# juggalette          3.989479e-09
# earns               3.258154e-09
#
# [7760 rows x 1 columns]

# %%
# Step 15a: Declare your TfidVectorizer object, but add the max_features parameter - 100 features
vec = TfidfVectorizer(max_features=100)

# Step 15b: Perform a fit_transform method with the 'cleaned_definition_nostop' column values
X2 = vec.fit_transform(corpus)

# Step 15c: Convert the sparse matrix into a new DataFrame
df_X2 = pd.DataFrame.sparse.from_spmatrix(X2, columns=vec.get_feature_names())

# %%
# Step 16a: Prepare your independent variables

# Step 16b: Split your data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df_X2, y, test_size=0.2, stratify=y)

# Step 16c: Train a RandomForestClassifier model (or other models)
rf2 = RandomForestClassifier()

# Step 16d: Make a new set of predictions
rf2.fit(X_train, y_train)
pred_rf2 = rf2.predict(X_test)

# Step 16e: Assess your prediction with f1_score and confusion_matrix
print(f1_score(y_test, pred_rf2))
print(confusion_matrix(y_test, pred_rf2))
# Out:
# 0.8333333333333334
# [[227  24]
#  [ 42 165]]

# %%
# Step 17a: Tweak your TfidVectorizer object
vec = TfidfVectorizer(max_features=850)
X2 = vec.fit_transform(corpus)
df_X2 = pd.DataFrame.sparse.from_spmatrix(X2, columns=vec.get_feature_names())

# Step 17b: Retrain your RandomForestClassifier model
X_train, X_test, y_train, y_test = train_test_split(df_X2, y, test_size=0.2, stratify=y)

rf2 = RandomForestClassifier()
rf2.fit(X_train, y_train)
pred_rf2 = rf2.predict(X_test)
print(f1_score(y_test, pred_rf2))
print(confusion_matrix(y_test, pred_rf2))
# Out:
# 0.8759493670886077
# [[236  15]
#  [ 34 173]]

# %%
# Step 18a: Declare a few strings containing mock definitions 
str1 = "problems bitch need machine gun"
str2 = "around world speak language booty explaining understand talk dirty"
str3 = "Mary had little lamb"

# Step 18b: Append the strings into a list
new_corpus = [str1,str2,str3]

# Step 18c: .transform these strings using the TfidfVectorizer object
new_X_test = vec.transform(new_corpus)

# Step 18d: Use the trained RandomForest model to predict what class your strings are
new_pred = rf2.predict(new_X_test)

print("new corpus prediction:", new_pred)
# Out:
# new corpus prediction: [1. 0. 0.]
